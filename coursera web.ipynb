# %%
m=int(input())
[a]=map(int,input().split())
n=int(input())
[b]=map(int,input().split())
c=[]
for i in range (m):
    for j in range (n):
        if b[j]==a[i]:
            c.appned(b[j])
print(m)

# %%
for _ in range(int(input())):
    n= (int(input())
    [a] = map(int,input().split())
    a.sort()
print(a)

# %%
import urllib.request
import re
url = "http://py4e-data.dr-chuck.net/regex_sum_535492.txt"
file = urllib.request.urlopen(url)
s=0
for line in file:
    decoded_line = line.decode("utf-8")
    y= re.findall('[0-9]+',decoded_line)
    for i in range(len(y)):
        s=s+int(y[i])
print(s)

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/intro-short.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if len(data) < 1:
        break
    print(data.decode(),end='')

mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Wed, 03 Jun 2020 22:32:11 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "1d3-54f6609240717"
# Accept-Ranges: bytes
# Content-Length: 467
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# Why should you learn to write programs?
#
# Writing programs (or programming) is a very creative
# and rewarding activity.  You can write programs for
# many reasons, ranging from making your living to solving
# a difficult data analysis problem to having fun to helping
# someone else solve a problem.  This book assumes that
# everyone needs to know how to program, and that once
# you know how to program you will figure out what you want
# to do with your newfound skills.

# %%
print(chr(108))
# Out:
# l

# %%
# To run this, download the BeautifulSoup zip file
# http://www.py4e.com/code3/bs4.zip
# and unzip it in the same directory as this file

from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, "html.parser")

# Retrieve all of the anchor tags
tags = soup('a')
for tag in tags:
    # Look at the parts of a tag
    print('TAG:', tag)
    print('URL:', tag.get('href', None))
    print('Contents:', tag.contents[0])
    print('Attrs:', tag.attrs)
# Out:
# Enter - http://py4e-data.dr-chuck.net/comments_42.html

# %%
# To run this, download the BeautifulSoup zip file
# http://www.py4e.com/code3/bs4.zip
# and unzip it in the same directory as this file

import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urllib.request.urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, 'html.parser')

# Retrieve all of the anchor tags
tags = soup('a')
for tag in tags:
    print(tag.get('href', None))

# %%
import urllib
import xml.etree.ElementTree as ET

# extract all the comment/count values from the url and get the sum of all of them
url = 'http://python-data.dr-chuck.net/comments_217218.xml'

# get the content of the url as a string
data = urllib.urlopen(url).read()

# transform the string content into a xml tree
tree = ET.fromstring(data)

# find all count elements
counts = tree.findall('comments/comment/count')

# extract the value of each count element and add it to the total
total = 0
for count in counts:
    total += int(count.text)

print 'total: ', total

# %%
import json
import urllib.request

count = 0
sum = 0
url = input("Enter Url - ")

data = urllib.request.urlopen(url).read()

print (data)

info = json.loads((data))

for i in info['comments']:
    count = count+1
    sum = sum + i['count']
print ("Sum : ",sum)   
print ("count : ",count)
# Out:
# Enter Url - http://py4e-data.dr-chuck.net/comments_535497.json
# b'{\n  "note":"This file contains the actual data for your assignment",\n  "comments":[\n    {\n      "name":"Athol",\n      "count":98\n    },\n    {\n      "name":"Allister",\n      "count":98\n    },\n    {\n      "name":"Davina",\n      "count":98\n    },\n    {\n      "name":"Mateusz",\n      "count":97\n    },\n    {\n      "name":"Anum",\n      "count":94\n    },\n    {\n      "name":"Elias",\n      "count":87\n    },\n    {\n      "name":"Abhinav",\n      "count":86\n    },\n    {\n      "name":"Nathanael",\n      "count":85\n    },\n    {\n      "name":"Carrick",\n      "count":84\n    },\n    {\n      "name":"Brendyn",\n      "count":83\n    },\n    {\n      "name":"Dora",\n      "count":79\n    },\n    {\n      "name":"Eirin",\n      "count":78\n    },\n    {\n      "name":"Xabier",\n      "count":78\n    },\n    {\n      "name":"Yadgor",\n      "count":77\n    },\n    {\n      "name":"Sahbian",\n      "count":73\n    },\n    {\n      "name":"Kevin",\n      "count":73\n    },\n    {\n      "name":"Kailyn",\n      "count":68\n    },\n    {\n      "name":"Nazzera",\n      "count":66\n    },\n    {\n      "name":"Keisha",\n      "count":65\n    },\n    {\n      "name":"Leaya",\n      "count":65\n    },\n    {\n      "name":"Israel",\n      "count":63\n    },\n    {\n      "name":"Patience",\n      "count":60\n    },\n    {\n      "name":"Sayeda",\n      "count":58\n    },\n    {\n      "name":"Tayo",\n      "count":58\n    },\n    {\n      "name":"Jordon",\n      "count":56\n    },\n    {\n      "name":"Sameer",\n      "count":53\n    },\n    {\n      "name":"Medina",\n      "count":52\n    },\n    {\n      "name":"Janet",\n      "count":51\n    },\n    {\n      "name":"Riha",\n      "count":49\n    },\n    {\n      "name":"Brodie",\n      "count":46\n    },\n    {\n      "name":"Oluwabukunmi",\n      "count":44\n    },\n    {\n      "name":"Rameesah",\n      "count":42\n    },\n    {\n      "name":"Rosalind",\n      "count":40\n    },\n    {\n      "name":"Lotti",\n      "count":40\n    },\n    {\n      "name":"Estelle",\n      "count":40\n    },\n    {\n      "name":"Sinead",\n      "count":39\n    },\n    {\n      "name":"Donald",\n      "count":39\n    },\n    {\n      "name":"Kelly",\n      "count":38\n    },\n    {\n      "name":"Jaia",\n      "count":38\n    },\n    {\n      "name":"Meabh",\n      "count":35\n    },\n    {\n      "name":"Romey",\n      "count":34\n    },\n    {\n      "name":"Jasveer",\n      "count":34\n    },\n    {\n      "name":"Maias",\n      "count":28\n    },\n    {\n      "name":"Shola",\n      "count":26\n    },\n    {\n      "name":"Hajirah",\n      "count":22\n    },\n    {\n      "name":"Logann",\n      "count":11\n    },\n    {\n      "name":"Carlee",\n      "count":11\n    },\n    {\n      "name":"Kyel",\n      "count":10\n    },\n    {\n      "name":"Hattie",\n      "count":6\n    },\n    {\n      "name":"Kizhi",\n      "count":5\n    }\n  ]\n}'
# Sum :  2760
# count :  50

# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))

    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)
# Out:
# Enter location: American University in Cairo
# Retrieving http://py4e-data.dr-chuck.net/json?address=American+University+in+Cairo&key=42
# Retrieved 1859 characters
# {
#     "results": [
#         {
#             "access_points": [],
#             "address_components": [
#                 {
#                     "long_name": "Road",
#                     "short_name": "Road",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "First New Cairo",
#                     "short_name": "First New Cairo",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Cairo Governorate",
#                     "short_name": "Cairo Governorate",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Egypt",
#                     "short_name": "EG",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "11835",
#                     "short_name": "11835",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "AUC Avenue\u060c Road\u060c First New Cairo, Cairo Governorate 11835, Egypt",
#             "geometry": {
#                 "location": {
#                     "lat": 30.018923,
#                     "lng": 31.499674
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.0202719802915,
#                         "lng": 31.5010229802915
#                     },
#                     "southwest": {
#                         "lat": 30.0175740197085,
#                         "lng": 31.4983250197085
#                     }
#                 }
#             },
#             "place_id": "ChIJ0Rb5-FoiWBQRxwXiQTG_6HU",
#             "plus_code": {
#                 "compound_code": "2F9X+HV New Cairo City, Egypt",
#                 "global_code": "8G2H2F9X+HV"
#             },
#             "types": [
#                 "establishment",
#                 "point_of_interest",
#                 "university"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# lat 30.018923 lng 31.499674
# AUC Avenue، Road، First New Cairo, Cairo Governorate 11835, Egypt

# %%
import math
import os
import random
import re
import sys

# Complete the birthday function below.
def birthday(s, d, m):
    if m<len(s):
        k=0
        for i in range(len(s)-m):
            sum=s[i]
            for j in range(1,m):
                sum=sum+s[i+j]
            if sum==d:
                k=k+1
        return k
    else:
        if d==s[0]:
            return 1
        else:
            return 0
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    s = list(map(int, input().rstrip().split()))

    dm = input().rstrip().split()

    d = int(dm[0])

    m = int(dm[1])

    result = birthday(s, d, m)

    fptr.write(str(result) + '\n')

    fptr.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-e222df751b70> in <module>
#      22             return 0
#      23 if __name__ == '__main__':
# ---> 24     fptr = open(os.environ['OUTPUT_PATH'], 'w')
#      25
#      26     n = int(input().strip())
#
# /usr/local/anaconda/lib/python3.6/os.py in __getitem__(self, key)
#     667         except KeyError:
#     668             # raise KeyError with the original key value
# --> 669             raise KeyError(key) from None
#     670         return self.decodevalue(value)
#     671
#
# KeyError: 'OUTPUT_PATH'

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the closestNumbers function below.
def closestNumbers(arr):
    arr.sort()
    diff=[]
    for i in range(1, len(arr)):
        diff.append(arr[i]-arr[i-1])
    p= diff.index(min(diff))
    print(p)
    arr1=[]
    arr1.append(arr[p])
    arr1.append(arr[p+1])
    return arr1
        

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input())

    arr = list(map(int, input().rstrip().split()))

    result = closestNumbers(arr)

    fptr.write(' '.join(map(str, result)))
    fptr.write('\n')

    fptr.close()

# %%
n, m = [int(i)  for i in raw_input().split()] 

#Create the datastructure, It shall be a list of list.
list_of_sequence = []
for i in range(n):
    list_of_sequence.append([])
lastans = 0   
for i in xrange(m):
    
    p,q,r = [int(i)  for i in raw_input().split()] 
    if p == 1:
        #Calculate the index.
        index = (q ^ lastans) % n
        list_of_sequence[index].append(r)
    elif p == 2:
        index = index = (q ^ lastans) % n
        element_index = r % len(list_of_sequence[index])
        value = list_of_sequence[index][element_index]
        lastans = value   
        print value

# %%
s="ramboob"
a=set(s)
c=s.count("r")
print(c)
# Out:
# 1
